# %%
 # Data Frames and Basic Data Pre-processing
import pandas as pd
dataframe = pd.DataFrame()    # Creating a Data Frame
df = pd.read_csv('/content/adult.csv')
print(df.head (2))
print("Dimensions: {}".format(df.shape))
df.describe()
# Out:
#    age workclass  fnlwgt education  educational-num      marital-status  \
# 0   25   Private  226802      11th                7       Never-married
# 1   38   Private   89814   HS-grad                9  Married-civ-spouse
#
#           occupation relationship   race gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black   Male             0             0
# 1    Farming-fishing      Husband  White   Male             0             0
#
#    hours-per-week native-country income
# 0              40  United-States  <=50K
# 1              50  United-States  <=50K
# Dimensions: (48842, 15)
#                 age        fnlwgt  educational-num  capital-gain  \
# count  48842.000000  4.884200e+04     48842.000000  48842.000000
# mean      38.643585  1.896641e+05        10.078089   1079.067626
# std       13.710510  1.056040e+05         2.570973   7452.019058
# min       17.000000  1.228500e+04         1.000000      0.000000
# ...

# %%
print(df.iloc[0])     # Navigating DataFrames
print(df.iloc[1:4])  # select three rows
print(df.iloc[:4])   # all rows up to and including the fourth row
# Out:
# age                               25
# workclass                    Private
# fnlwgt                        226802
# education                       11th
# educational-num                    7
# marital-status         Never-married
# occupation         Machine-op-inspct
# relationship               Own-child
# race                           Black
# gender                          Male
# capital-gain                       0
# capital-loss                       0
# hours-per-week                    40
# native-country         United-States
# income                         <=50K
# Name: 0, dtype: object
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
#
# ...

# %%
# Select rows where 'Sex' column is 'female' and get the first two rows
female_rows = df[df['gender'] == 'Female'].head(2)
print(female_rows)
# multiple conditions
female_multiple =df [(df ['gender'] == 'Female') & (df ['age'] >= 65)]
print(female_multiple)
# Out:
#    age workclass  fnlwgt     education  educational-num marital-status  \
# 4   18         ?  103497  Some-college               10  Never-married
# 8   24   Private  369667  Some-college               10  Never-married
#
#       occupation relationship   race  gender  capital-gain  capital-loss  \
# 4              ?    Own-child  White  Female             0             0
# 8  Other-service    Unmarried  White  Female             0             0
#
#    hours-per-week native-country income
# 4              30  United-States  <=50K
# 8              40  United-States  <=50K
#        age         workclass  fnlwgt     education  educational-num  \
# 22      72                 ?  132015       7th-8th                4
# 125     69           Private  183791       HS-grad                9
# 437     75                 ?   26586          10th                6
# 475     73  Self-emp-not-inc  151255  Some-college               10
# ...

# %%
df['gender'].replace('Female', 'Woman', inplace=True)  #replacing value
print(df.head(5))
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black   Male             0             0
# 1    Farming-fishing      Husband  White   Male             0             0
# 2    Protective-serv      Husband  White   Male             0             0
# 3  Machine-op-inspct      Husband  Black   Male          7688             0
# 4                  ?    Own-child  White  Woman             0             0
#
#    hours-per-week native-country income
# ...

# %%
# Renaming Columnc
df = df.rename(columns={'workclass': 'Work Class'}) #single columnes
df.head(2)

df = df.rename(columns={   #multiple columnes
    'age': 'Age',
    'workclass': 'Work Class',
    'education': 'Education Level',
    'marital-status': 'Marital Status',
})
df.head(2)
# Out:
#    Age Work Class  fnlwgt Education Level  educational-num  \
# 0   25    Private  226802            11th                7
# 1   38    Private   89814         HS-grad                9
#
#        Marital Status         occupation relationship   race gender  \
# 0       Never-married  Machine-op-inspct    Own-child  Black   Male
# 1  Married-civ-spouse    Farming-fishing      Husband  White   Male
#
#    capital-gain  capital-loss  hours-per-week native-country income
# 0             0             0              40  United-States  <=50K
# 1             0             0              50  United-States  <=50K

# %%
# 3.7 Finding the Min, Max, Sum, Average, and Count for the 'age' column
print(df.columns)
print("Minimum Age:", df['Age'].min())
print("Maximum Age:", df['Age'].max())
print("Sum of Ages:", df['Age'].sum())
print("Average Age:", df['Age'].mean())
print("Count of Age values:", df['Age'].count())
# Out:
# Index(['Age', 'Work Class', 'fnlwgt', 'Education Level', 'educational-num',
#        'Marital Status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')
# Minimum Age: 17
# Maximum Age: 90
# Sum of Ages: 1887430
# Average Age: 38.64358543876172
# Count of Age values: 48842

# %%
numeric_df = df.select_dtypes(include=['int64', 'float64']) # Select only numeric columns
print("Variance:\n", numeric_df.var(), "\n")
print("Standard Deviation:\n", numeric_df.std(), "\n")
print("Kurtosis:\n", numeric_df.kurt(), "\n")
print("Skewness:\n", numeric_df.skew(), "\n")
# Out:
# Variance:
#  Age                1.879781e+02
# fnlwgt             1.115221e+10
# educational-num    6.609901e+00
# capital-gain       5.553259e+07
# capital-loss       1.624127e+05
# hours-per-week     1.535479e+02
# dtype: float64
#
# Standard Deviation:
#  Age                    13.710510
# fnlwgt             105604.025423
# educational-num         2.570973
# capital-gain         7452.019058
# capital-loss          403.004552
# hours-per-week         12.391444
# dtype: float64
#
# Kurtosis:
#  Age                 -0.184269
# fnlwgt               6.057848
# educational-num      0.625745
# capital-gain       152.693096
# capital-loss        20.014346
# hours-per-week       2.951059
# dtype: float64
#
# Skewness:
#  Age                 0.557580
# fnlwgt              1.438892
# educational-num    -0.316525
# capital-gain       11.894659
# capital-loss        4.569809
# hours-per-week      0.238750
# dtype: float64

# %%
df ['gender'].unique()  # Finding Unique Values
df ['gender'].value_counts()
# Out:
# gender
# Male     32650
# Woman    16192
# Name: count, dtype: int64

# %%
# Handling Missing Values
import numpy as np

df.replace('?', np.nan, inplace=True)
df.isnull().sum()

print(df.columns)
df.head(5)
# Out:
# Index(['Age', 'Work Class', 'fnlwgt', 'Education Level', 'educational-num',
#        'Marital Status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')
#    Age Work Class  fnlwgt Education Level  educational-num  \
# 0   25    Private  226802            11th                7
# 1   38    Private   89814         HS-grad                9
# 2   28  Local-gov  336951      Assoc-acdm               12
# 3   44    Private  160323    Some-college               10
# 4   18        NaN  103497    Some-college               10
#
#        Marital Status         occupation relationship   race gender  \
# 0       Never-married  Machine-op-inspct    Own-child  Black   Male
# 1  Married-civ-spouse    Farming-fishing      Husband  White   Male
# 2  Married-civ-spouse    Protective-serv      Husband  White   Male
# 3  Married-civ-spouse  Machine-op-inspct      Husband  Black   Male
# ...

# %%
# Deleting Columns
df.drop('educational-num', axis=1, inplace=True)   #Deleting a column

# %%
df.drop(5, axis=0, inplace=True)   # Deleting a raw
df.drop([5, 10], axis=0, inplace=True)  # delete rows 5 and 10

# %%
df = df[df['Age'] >= 18]  # delete all rows where age is less than 18

# %%
df = df[df['gender'].notnull()]   #delete rows where gender is missing
df.dropna(inplace=True)   # row that contains any NaN
df = df.iloc[10:]             # first 10 rows
df = df[df['Work Class'] != 'Private']   # where workclass is not "Private"

# %% [markdown]
# Grouping Rows by Values

# %%
df.groupby('gender').mean(numeric_only=True)
# Out:
#               Age         fnlwgt  capital-gain  capital-loss  hours-per-week
# gender
# Male    39.703175  191760.369254   1338.242542    101.081795       42.598566
# Woman   37.297792  185791.146883    589.084230     61.903378       36.716487

# %%
df.groupby('gender')['Age'].mean()
# Out:
# gender
# Male     39.703175
# Woman    37.297792
# Name: Age, dtype: float64

# %%
df.groupby('income')['Age'].mean().reset_index()
# Out:
#   income        Age
# 0  <=50K  37.195684
# 1   >50K  44.275178

# %% [markdown]
# Looping Over a Column

# %%
for country in df['native-country'][0:2]:
    print(country.upper())
# Out:
# UNITED-STATES
# UNITED-STATES

# %%
df['native-country'].fillna('', inplace=True)  #3.16 Applying a Function Over All Elements in a Column
def uppercase(x):
    return x.upper()
df['native-country'].apply(uppercase)[0:2]
# Out:
# 0    UNITED-STATES
# 1    UNITED-STATES
# Name: native-country, dtype: object

# %%
# Applying a Function to Groups
df.groupby('gender').apply(lambda x: x.count())
# Out:
# /tmp/ipython-input-1154302902.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.groupby('gender').apply(lambda x: x.count())
#           Age  fnlwgt  Marital Status  occupation  relationship   race  \
# gender
# Male    32349   32349           32349       30863         32349  32349
# Woman   15897   15897           15897       14673         15897  15897
#
#         gender  capital-gain  capital-loss  hours-per-week  native-country  \
# gender
# Male     32349         32349         32349           32349           32349
# Woman    15897         15897         15897           15897           15897
#
#         income
# gender
# Male     32349
# Woman    15897

# %%
df.sort_values('Age', ascending=False) # desending
# Out:
#        Age  fnlwgt      Marital Status       occupation    relationship  \
# 18216   90  221832  Married-civ-spouse  Exec-managerial         Husband
# 17321   90  137018       Never-married    Other-service   Not-in-family
# 22513   90  155981  Married-civ-spouse   Prof-specialty         Husband
# 32173   90   88991  Married-civ-spouse  Exec-managerial            Wife
# 11871   90   50746            Divorced              NaN   Not-in-family
# ...    ...     ...                 ...              ...             ...
# 34188   18  131180       Never-married   Prof-specialty       Own-child
# 36893   18  189041       Never-married              NaN  Other-relative
# 5015    18  161245       Never-married  Farming-fishing       Own-child
# 34161   18   76142       Never-married    Other-service       Own-child
# 36875   18  216730       Never-married    Other-service       Own-child
#
#         race gender  capital-gain  capital-loss  hours-per-week  \
# ...

# %%
df.sort_values(['gender', 'Age'], ascending=[True, False]) #sorting multiple col
# Out:
#        Age  fnlwgt      Marital Status        occupation   relationship  \
# 899     90  149069  Married-civ-spouse             Sales        Husband
# 3496    90   83601             Widowed    Prof-specialty  Not-in-family
# 6976    90  250832  Married-civ-spouse  Transport-moving        Husband
# 7414    90  227796       Never-married   Exec-managerial  Not-in-family
# 7419    90  122348  Married-civ-spouse    Prof-specialty        Husband
# ...    ...     ...                 ...               ...            ...
# 48351   18   97474       Never-married               NaN      Own-child
# 48468   18  119655       Never-married      Adm-clerical      Own-child
# 48492   18  180039       Never-married             Sales      Own-child
# 48616   18  156608       Never-married               NaN      Own-child
# 48724   18   41381       Never-married             Sales      Own-child
#
#         race gender  capital-gain  capital-loss  hours-per-week  \
# ...

# %%
import pandas as pd  #conacting

df1 = pd.DataFrame({'A': [1, 2], 'B': [3, 4]})
df2 = pd.DataFrame({'A': [5, 6], 'B': [7, 8]})

pd.concat([df1, df2], axis=0)
# Out:
#    A  B
# 0  1  3
# 1  2  4
# 0  5  7
# 1  6  8

# %%
normal = pd.merge(df1, df2, on="income", how="left")  #normal merge, no sorting
normal.head()
ordered = merge_ordered(df1, df2, on="income")  #sorted + ordered merge
ordered.head()
# Out:
#    Age gender income    Avg_Age
# 0   25   Male  <=50K  37.195684
# 1   38   Male  <=50K  37.195684
# 2   18  Woman  <=50K  37.195684
# 3   29   Male  <=50K  37.195684
# 4   24  Woman  <=50K  37.195684

# %%
# df1: keep Age, gender, income
df1 = df[['Age', 'gender', 'income']]
# df2: create a summary table of average Age by income group
df2 = df.groupby('income')[['Age']].mean().reset_index()
df2.rename(columns={'Age': 'Avg_Age'}, inplace=True)
merged_normal = pd.merge(df1, df2, on='income', how='left')
print(merged_normal.head())

from pandas import merge_ordered
merged_ordered = merge_ordered(df1, df2, on='income')
print(merged_ordered.head())
# Out:
#    Age gender income    Avg_Age
# 0   25   Male  <=50K  37.195684
# 1   38   Male  <=50K  37.195684
# 2   28   Male   >50K  44.275178
# 3   44   Male   >50K  44.275178
# 4   18  Woman  <=50K  37.195684
#    Age gender income    Avg_Age
# 0   25   Male  <=50K  37.195684
# 1   38   Male  <=50K  37.195684
# 2   18  Woman  <=50K  37.195684
# 3   29   Male  <=50K  37.195684
# 4   24  Woman  <=50K  37.195684

# %%
import pandas as pd
from pandas import merge_ordered
df1 = pd.DataFrame({'Date': ['2020-01', '2020-02', '2020-03'],'Sales_A': [100, 120, 140]})
df2 = pd.DataFrame({ 'Date': ['2020-02', '2020-03', '2020-04'],'Sales_B': [90, 110, 130]})
result = merge_ordered(df1, df2, on='Date')
print(result)
# Out:
#       Date  Sales_A  Sales_B
# 0  2020-01    100.0      NaN
# 1  2020-02    120.0     90.0
# 2  2020-03    140.0    110.0
# 3  2020-04      NaN    130.0

# %%
df.query("Age > 50") #filtering using query
# Out:
#        Age  fnlwgt      Marital Status         occupation   relationship  \
# 7       63  104626  Married-civ-spouse     Prof-specialty        Husband
# 9       55  104996  Married-civ-spouse       Craft-repair        Husband
# 10      65  184454  Married-civ-spouse  Machine-op-inspct        Husband
# 13      58  299831  Married-civ-spouse                NaN        Husband
# 22      72  132015            Divorced                NaN  Not-in-family
# ...    ...     ...                 ...                ...            ...
# 48823   72  129912  Married-civ-spouse                NaN        Husband
# 48829   65   99359       Never-married     Prof-specialty  Not-in-family
# 48835   53  321865  Married-civ-spouse    Exec-managerial        Husband
# 48839   58  151910             Widowed       Adm-clerical      Unmarried
# 48841   52  287927  Married-civ-spouse    Exec-managerial           Wife
#
#         race gender  capital-gain  capital-loss  hours-per-week  \
# ...

# %%
df[df['occupation'].isin(['Tech-support', 'Sales', 'Exec-managerial'])] #filtering using isin
# Out:
#        Age  fnlwgt      Marital Status       occupation   relationship  \
# 15      43  346189  Married-civ-spouse  Exec-managerial        Husband
# 20      34  107914  Married-civ-spouse     Tech-support        Husband
# 30      46  106444  Married-civ-spouse  Exec-managerial        Husband
# 32      24  188274       Never-married            Sales  Not-in-family
# 34      26   43311            Divorced  Exec-managerial      Unmarried
# ...    ...     ...                 ...              ...            ...
# 48833   43   84661  Married-civ-spouse            Sales        Husband
# 48834   32  116138       Never-married     Tech-support  Not-in-family
# 48835   53  321865  Married-civ-spouse  Exec-managerial        Husband
# 48837   27  257302  Married-civ-spouse     Tech-support           Wife
# 48841   52  287927  Married-civ-spouse  Exec-managerial           Wife
#
#                      race gender  capital-gain  capital-loss  hours-per-week  \
# ...

# %% [markdown]
# Effective Strategies for Handling Missing Values

# %%
# 1. Deleting the Missing Values
import numpy as np
df = df.replace("?", np.nan)

# %%
df = df.dropna(axis=0)
df.isnull().sum()
# Out:
# age                0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
df = df.drop(['workclass'],axis=1)
df.isnull().sum()
# Out:
# age                0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
# 2. Imputing the Missing Values
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer
df = pd.read_csv("/content/adult.csv")
df = df.replace("?", np.nan)
print("Missing values in each column:")
print(df.isnull().sum())

# 3. Separate numeric and categorical columns
numeric_cols = df.select_dtypes(include=[np.number]).columns
categorical_cols = df.select_dtypes(include=["object"]).columns

# 4. Impute numeric columns using mean
num_imputer = SimpleImputer(strategy="mean")
df[numeric_cols] = num_imputer.fit_transform(df[numeric_cols])

# 5. Impute categorical columns using most frequent value (mode)
cat_imputer = SimpleImputer(strategy="most_frequent")
df[categorical_cols] = cat_imputer.fit_transform(df[categorical_cols])

print("\nMissing values after imputation:")
print(df.isnull().sum())
# Out:
# Missing values in each column:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64
#
# Missing values after imputation:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
import numpy as np
import pandas as pd
from sklearn.impute import KNNImputer
import matplotlib.pyplot as plt
df = df.replace("?", np.nan)
# Label encode categorical columns without destroying NaN
for col in df.select_dtypes(include="object").columns:
    df[col] = df[col].astype("category")
    df[col] = df[col].cat.codes.replace({-1: np.nan})

imputer = KNNImputer(n_neighbors=5)
df_imputed = pd.DataFrame(imputer.fit_transform(df), columns=df.columns)
missing_after = df_imputed.isnull().sum()
plt.figure(figsize=(14,6))
plt.subplot(1,2,2)
plt.bar(missing_after.index, missing_after.values)
plt.xticks(rotation=90)
plt.title("After Imputation")
plt.tight_layout()
plt.show()

# %%
print(df.head(10))
# Out:
#    age  workclass  fnlwgt  education  educational-num  marital-status  \
# 0   25          3  226802          1                7               4
# 1   38          3   89814         11                9               2
# 2   28          1  336951          7               12               2
# 3   44          3  160323         15               10               2
# 4   18          8  103497         15               10               4
# 5   34          3  198693          0                6               4
# 6   29          8  227026         11                9               4
# 7   63          5  104626         14               15               2
# 8   24          3  369667         15               10               4
# 9   55          3  104996          5                4               2
#
#    occupation  relationship  race  gender  capital-gain  capital-loss  \
# 0           6             3     2       1             0             0
# ...
